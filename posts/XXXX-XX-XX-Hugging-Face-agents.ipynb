# %% [markdown]
# # Hugging Face agents

# %% [markdown]
# Los agentes de Hugging Face es una API para utilizar herramientas de IA mediante el uso de lenguaje natural. Para poder usar los agentes de Hugging Face, primero debemos instalar la librería `transformers` de Hugging Face. Para ello, ejecutamos el siguiente comando:
#
# ```bash
# pip install "transformers[agents]"
# ```

# %% [markdown]
# ## Agents endpoints

# %% [markdown]
# Hugging Face ofrece tres endpoints para crear agentes: OpenAI, BigCode y OpenAssistant. Para el primero hace falta una API KEY de OpenAI, mientras que para los otros dos hace falta un token de Hugging Face. En este notebook vamos a utilizar el endpoint de OpenAI, para ello necesitamos instalar la librería de OpenAI:
#
# ``` bash
# pip install openai
# ```

# %% [markdown]
# ### Instanciar el agente

# %% [markdown]
# Una vez nos hemos logueado en Hugging Face, podemos instanciar el agente. Como hemos dicho vamos a usar el endpoint de BigCode, pero voy a dejar otros endpoints por si los quieres probar

# %%
import getpass
from transformers import OpenAiAgent

pswd = getpass.getpass('OpenAI API key:')
agent = OpenAiAgent(model="gpt-4-turbo", api_key=pswd)
# Out:
# tool_config.json:   0%|          | 0.00/331 [00:00<?, ?B/s]

# %% [markdown]
# ### Uso del agente

# %% [markdown]
# Una vez hemos instanciado el agente le podemos pedir tareas con el método `run`

# %%
agent.run("Crea una foto de una llama en la playa")
# Out:
# You're loading a tool from the Hub from None. Please make sure this is a source that you trust as the code within that tool will be executed on your machine. Always verify the code of the tools that you load. We recommend specifying a `revision` to ensure you're loading the code that you have checked.
# ==Explanation from the agent==
# I will use the following tool: `image_generator` to create an image based on the description provided.
#
#
# ==Code generated by the agent==
# image = image_generator(prompt="una llama en la playa")
#
#
# ==Result==
# text_to_image.py:   0%|          | 0.00/1.86k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/spaces/huggingface-tools/text-to-image:
# - text_to_image.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 agent.run("Crea una foto de una llama en la playa")
#
# File ~/miniconda3/envs/hf_agents/lib/python3.11/site-packages/transformers/tools/agents.py:356, in Agent.run(self, task, return_code, remote, **kwargs)
#     354 if not return_code:
#     355     self.log("\n\n==Result==")
# --> 356     self.cached_tools = resolve_tools(code, self.toolbox, remote=remote, cached_tools=self.cached_tools)
#     357     return evaluate(code, self.cached_tools, state=kwargs.copy())
#     358 else:
#
# File ~/miniconda3/envs/hf_agents/lib/python3.11/site-packages/transformers/tools/agents.py:141, in resolve_tools(code, toolbox, remote, cached_tools)
#     139         task_or_repo_id = tool.task if tool.repo_id is None else tool.repo_id
#     140         _remote = remote and supports_remote(task_or_repo_id)
# --> 141         resolved_tools[name] = load_tool(task_or_repo_id, remote=_remote)
#     143 return resolved_tools
#
# File ~/miniconda3/envs/hf_agents/lib/python3.11/site-packages/transformers/tools/base.py:702, in load_tool(task_or_repo_id, model_repo_id, remote, token, **kwargs)
#     695 else:
#     696     logger.warning_once(
#     697         f"You're loading a tool from the Hub from {model_repo_id}. Please make sure this is a source that you "
#     698         f"trust as the code within that tool will be executed on your machine. Always verify the code of "
#     699         f"the tools that you load. We recommend specifying a `revision` to ensure you're loading the "
#     700         f"code that you have checked."
#     701     )
# --> 702     return Tool.from_hub(task_or_repo_id, model_repo_id=model_repo_id, token=token, remote=remote, **kwargs)
#
# File ~/miniconda3/envs/hf_agents/lib/python3.11/site-packages/transformers/tools/base.py:273, in Tool.from_hub(cls, repo_id, model_repo_id, token, remote, **kwargs)
#     270     custom_tool = config
#     272 tool_class = custom_tool["tool_class"]
# --> 273 tool_class = get_class_from_dynamic_module(tool_class, repo_id, token=token, **hub_kwargs)
#     275 if len(tool_class.name) == 0:
#     276     tool_class.name = custom_tool["name"]
#
# File ~/miniconda3/envs/hf_agents/lib/python3.11/site-packages/transformers/dynamic_module_utils.py:501, in get_class_from_dynamic_module(class_reference, pretrained_model_name_or_path, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, repo_type, code_revision, **kwargs)
#     488 # And lastly we get the class inside our newly created module
#     489 final_module = get_cached_module_file(
#     490     repo_id,
#     491     module_file + ".py",
#    (...)
#     499     repo_type=repo_type,
#     500 )
# --> 501 return get_class_in_module(class_name, final_module)
#
# File ~/miniconda3/envs/hf_agents/lib/python3.11/site-packages/transformers/dynamic_module_utils.py:201, in get_class_in_module(class_name, module_path)
#     199 name = os.path.normpath(module_path).replace(".py", "").replace(os.path.sep, ".")
#     200 module_path = str(Path(HF_MODULES_CACHE) / module_path)
# --> 201 module = importlib.machinery.SourceFileLoader(name, module_path).load_module()
#     202 return getattr(module, class_name)
#
# File <frozen importlib._bootstrap_external>:605, in _check_name_wrapper(self, name, *args, **kwargs)
#
# File <frozen importlib._bootstrap_external>:1120, in load_module(self, fullname)
#
# File <frozen importlib._bootstrap_external>:945, in load_module(self, fullname)
#
# File <frozen importlib._bootstrap>:290, in _load_module_shim(self, fullname)
#
# File <frozen importlib._bootstrap>:721, in _load(spec)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/.cache/huggingface/modules/transformers_modules/huggingface-tools/text-to-image/e14735916d1c593cd2f4624c4e3872879245d1b9/text_to_image.py:2
#       1 from PIL import Image
# ----> 2 from transformers.agents.tools import Tool
#       3 from transformers.utils import is_accelerate_available
#       4 import torch
#
# ModuleNotFoundError: No module named 'transformers.agents'
