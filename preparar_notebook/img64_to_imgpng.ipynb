# %%
image_64 = "..."

# %%
import base64

image_data = base64.b64decode(image_64)

# Guardar la imagen en un archivo
with open('output_image.png', 'wb') as image_file:
    image_file.write(image_data)

print("La imagen se ha guardado como output_image.png")
# Out:
# La imagen se ha guardado como output_image.png

# %%
from PIL import Image

image_png = "output_image.png"
img = Image.open(image_png)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=362x248>
